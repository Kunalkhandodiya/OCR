# %%
import easyocr

# %%
#download the model
reader = easyocr.Reader(['en'], gpu = False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
# show an image
import PIL
from PIL import ImageDraw
im = PIL.Image.open("invoice1.png")
#im = PIL.Image.open("france.jfif")

im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=820x531>

# %%
# Doing OCR. Get bounding boxes.
bounds = reader.readtext('invoice1.png')
bounds
# Out:
# [([[52, 71], [324, 71], [324, 104], [52, 104]],
#   'COMPANY NAME',
#   0.985341077696225),
#  ([[593, 97], [675, 97], [675, 111], [593, 111]],
#   'Street A ddress',
#   0.6676528868999823),
#  ([[593, 111], [695, 111], [695, 127], [593, 127]],
#   'City , ST ZIP Code',
#   0.6104072618117106),
#  ([[591, 129], [629, 129], [629, 143], [591, 143]],
#   'E-mail',
#   0.9766624385337339),
#  ([[593, 145], [651, 145], [651, 159], [593, 159]],
#   'Phone No.',
#   0.5830421524543631),
#  ([[50, 162], [174, 162], [174, 188], [50, 188]],
#   'Customer:',
#   0.9986561391879775),
#  ([[591, 171], [639, 171], [639, 185], [591, 185]],
#   'VATNo.',
#   0.817353570164592),
#  ([[49, 193], [85, 193], [85, 207], [49, 207]], 'Name', 0.5496030915392337),
#  ([[51, 209], [133, 209], [133, 223], [51, 223]],
#   'Street A ddress',
#   0.6065356341351473),
#  ([[591, 209], [655, 209], [655, 223], [591, 223]],
#   'Invoice No',
#   0.9761421883897489),
#  ([[51, 223], [153, 223], [153, 239], [51, 239]],
#   'City , ST ZIP Code',
#   0.7615239377695369),
#  ([[591, 225], [671, 225], [671, 239], [591, 239]],
#   'Invoice Date:',
#   0.9878685734204452),
#  ([[51, 243], [89, 243], [89, 259], [51, 259]], 'E-mail', 0.9036796401430088),
#  ([[587, 243], [723, 243], [723, 259], [587, 259]],
#   'Payment Tems 30 Days',
#   0.8513524906957923),
#  ([[51, 259], [107, 259], [107, 275], [51, 275]],
#   'Phone No_',
#   0.9992299359752125),
#  ([[432, 280], [732, 280], [732, 312], [432, 312]],
#   'Commission Invoice',
#   0.9576429411638993),
#  ([[277, 341], [343, 341], [343, 355], [277, 355]],
#   'Price wlout',
#   0.9997062457822786),
#  ([[363, 341], [419, 341], [419, 355], [363, 355]],
#   'Price with',
#   0.9997712753561971),
#  ([[439, 341], [503, 341], [503, 355], [439, 355]],
#   'Total wout',
#   0.7168555344563904),
#  ([[523, 341], [577, 341], [577, 355], [523, 355]],
#   'Total wth',
#   0.6246461675021989),
#  ([[599, 341], [669, 341], [669, 355], [599, 355]],
#   'Commission',
#   0.9996695892506067),
#  ([[51, 349], [79, 349], [79, 363], [51, 363]], 'Date', 0.9999945163726807),
#  ([[97, 349], [161, 349], [161, 365], [97, 365]],
#   'Description',
#   0.9999882106656085),
#  ([[189, 349], [211, 349], [211, 363], [189, 363]], 'Qty', 0.99708023625487),
#  ([[685, 349], [755, 349], [755, 363], [685, 363]],
#   'Net A mount',
#   0.6948830935804086),
#  ([[275, 357], [343, 357], [343, 371], [275, 371]],
#   'commission',
#   0.999923623600871),
#  ([[357, 357], [425, 357], [425, 371], [357, 371]],
#   'commission',
#   0.9991721159948774),
#  ([[437, 357], [503, 357], [503, 371], [437, 371]],
#   'commission',
#   0.9998895057032423),
#  ([[517, 357], [585, 357], [585, 371], [517, 371]],
#   'commission',
#   0.9999446217938129),
#  ([[611, 357], [657, 357], [657, 371], [611, 371]],
#   'Amount',
#   0.9991819300346322),
#  ([[49, 385], [89, 385], [89, 399], [49, 399]], '10.6.04', 0.742544173164269),
#  ([[97, 385], [173, 385], [173, 401], [97, 401]],
#   'Case of soda',
#   0.733040215224791),
#  ([[189, 385], [211, 385], [211, 401], [189, 401]], '100', 0.9926590427523999),
#  ([[233, 385], [255, 385], [255, 401], [233, 401]], '5.0', 0.9945952347935778),
#  ([[311, 385], [345, 385], [345, 401], [311, 401]],
#   '50.00',
#   0.8859257035691427),
#  ([[393, 385], [425, 385], [425, 401], [393, 401]],
#   '52.50',
#   0.9658828986022836),
#  ([[453, 385], [505, 385], [505, 401], [453, 401]],
#   '5,000.00',
#   0.907069838050655),
#  ([[537, 385], [587, 385], [587, 401], [537, 401]],
#   '5,250.00',
#   0.9724471416213549),
#  ([[629, 385], [671, 385], [671, 401], [629, 401]],
#   '250.00',
#   0.9522205178238758),
#  ([[707, 385], [757, 385], [757, 401], [707, 401]],
#   '5,000.00',
#   0.9643690293579344),
#  ([[231, 411], [257, 411], [257, 427], [231, 427]],
#   '10.0',
#   0.9995216131210327),
#  ([[305, 411], [345, 411], [345, 427], [305, 427]],
#   '100.00',
#   0.6425103825307269),
#  ([[393, 411], [425, 411], [425, 427], [393, 427]],
#   '10.00',
#   0.9974846853389097),
#  ([[453, 413], [505, 413], [505, 427], [453, 427]],
#   '5,000.00',
#   0.9410922424973651),
#  ([[545, 411], [587, 411], [587, 427], [545, 427]],
#   '500.00',
#   0.8908876877510751),
#  ([[629, 411], [671, 411], [671, 427], [629, 427]],
#   '500.00',
#   0.83626652773303),
#  ([[707, 411], [757, 411], [757, 427], [707, 427]],
#   '5,000.00',
#   0.9643690293579344)]

# %%
# Draw bounding boxes
def draw_boxes(image, bounds, color='yellow', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bounds)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=820x531>

# %%
len(bounds)
# Out:
# 47

# %%
for i in bounds:
    print(i[1])
# Out:
# COMPANY NAME
# Street A ddress
# City , ST ZIP Code
# E-mail
# Phone No.
# Customer:
# VATNo.
# Name
# Street A ddress
# Invoice No
# City , ST ZIP Code
# Invoice Date:
# E-mail
# Payment Tems 30 Days
# Phone No_
# Commission Invoice
# Price wlout
# Price with
# Total wout
# Total wth
# Commission
# Date
# Description
# Qty
# Net A mount
# commission
# commission
# commission
# commission
# Amount
# 10.6.04
# Case of soda
# 100
# 5.0
# 50.00
# 52.50
# 5,000.00
# 5,250.00
# 250.00
# 5,000.00
# 10.0
# 100.00
# 10.00
# 5,000.00
# 500.00
# 500.00
# 5,000.00
